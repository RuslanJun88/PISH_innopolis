# %% [markdown]
# <a href="https://colab.research.google.com/github/RuslanJun88/PISH_innopolis/blob/main/%20%D0%98%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Git%20%D0%B4%D0%BB%D1%8F%20%D0%BA%D0%BE%D0%BD%D1%82%D1%80%D0%BE%D0%BB%D1%8F%20%D0%B7%D0%B0%20%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D0%BE%D0%BD%D0%BD%D0%BE%D1%81%D1%82%D1%8C%D1%8E%20%D0%B8%20%D1%81%D0%BE%D0%B2%D0%BC%D0%B5%D1%81%D1%82%D0%BD%D0%BE%D0%B9%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B%2018_28082023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #подключение библиотеки pandas дял работы  сбазами данных./+

# %%
data=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Files for lessons/world-data-2023.xlsx') #чтение базы данных в формате csv из google_drive./+
data                                                                                              #вывод данных
# Out:
#          Country Density\n(P/Km2) Abbreviation  Agricultural Land( %)  \
# 0    Afghanistan               60           AF                  0.581
# 1        Albania              105           AL                  0.431
# 2        Algeria               18           DZ                  0.174
# 3        Andorra              164           AD                  0.400
# 4         Angola               26           AO                  0.475
# ..           ...              ...          ...                    ...
# 190    Venezuela               32           VE                  0.245
# 191      Vietnam              314           VN                  0.393
# 192        Yemen               56           YE                  0.446
# 193       Zambia               25           ZM                  0.321
# 194     Zimbabwe               38           ZW                  0.419
#
#      Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# ...

# %%
data.info()     #Информация о датафрейме
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    float64
#  4   Land Area(Km2)                             194 non-null    float64
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %%
data.isnull()                               #Проверка на пустые ячеки
is_null=data.isnull()                       #Присвоение датафрейму с пустыми ячейками новую переменную

# %%
rows_with_null = data[is_null.any(axis=1)]  #Создание датафрейма, где хотя бы в одном столбце есть пустое значение
rows_with_null.isnull()                     #Вывод строк с отсутсвующими данными в ячейках с параметром  "True"
# Out:
#      Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 3      False             False         False                  False
# 5      False             False         False                  False
# 9      False             False         False                  False
# 11     False             False         False                  False
# 12     False             False         False                  False
# ..       ...               ...           ...                    ...
# 188    False             False         False                  False
# 189    False             False         False                  False
# 190    False             False         False                  False
# 192    False             False         False                  False
# 194    False             False         False                  False
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 3             False               True       False         False
# ...

# %%
rows_with_null                             #Вывод строк с отсутсвующими данными в ячейках
# Out:
#                  Country Density\n(P/Km2) Abbreviation  Agricultural Land( %)  \
# 3                Andorra              164           AD                  0.400
# 5    Antigua and Barbuda              223           AG                  0.205
# 9                Austria              109           AT                  0.324
# 11           The Bahamas               39           BS                  0.014
# 12               Bahrain            2,239           BH                  0.111
# ..                   ...              ...          ...                    ...
# 188           Uzbekistan               79           UZ                  0.629
# 189              Vanuatu               25           VU                  0.153
# 190            Venezuela               32           VE                  0.245
# 192                Yemen               56           YE                  0.446
# 194             Zimbabwe               38           ZW                  0.419
#
# ...

# %%
data.corr()

 # Матрица корреляции
            # BirthRate(рождаемость) имеет положительную корреляцию с Fertility Rate(коэффициентом рождаемости)
            # с Infant mortality(Младенческая смертность) , c Maternal mortality ratio и отрицательную корреляцию с Physicians per thousand(врачей на тысячу)
            # Это говорит нам, что при высокой рождаемости и высоком коэффициенте рождаемости, смертность младенцев и матерей высокая, из-за недостатвка медицинского персонала. По этой же причине продолжительность жизни небольшая.
# Out:
# <ipython-input-8-4ce9c61d430a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                            Agricultural Land( %)  \
# Agricultural Land( %)                                   1.000000
# Land Area(Km2)                                         -0.039559
# Birth Rate                                              0.199269
# Calling Code                                           -0.067008
# CPI Change (%)                                         -0.010878
# Fertility Rate                                          0.180507
# Forested Area (%)                                      -0.434570
# Gasoline Price                                          0.047724
# GDP                                                     0.051840
# ...

# %%
samp10=data.sample(10)  #Создание случайной выборки из 10 строк и присвоение её переменной
samp10                  #Вывод данных присвоенной новой переменной
# Out:
#           Country Density\n(P/Km2) Abbreviation  Agricultural Land( %)  \
# 124     Nicaragua               55           NI                  0.421
# 97          Libya                4           LY                  0.087
# 155  Sierra Leone              111           SL                  0.547
# 96        Liberia               53           LR                  0.280
# 92           Laos               32           LA                  0.103
# 80           Iraq               93           IQ                  0.214
# 27        Burundi              463           BI                  0.792
# 114      Mongolia                2           MN                  0.715
# 24         Brunei               83           BN                  0.027
# 132         Palau               39           PW                  0.109
#
#      Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 124         13037.0                12       20.64         505.0
# ...

# %%
samp10['Land Area(Km2)'].sum()           #Применение функци сложения к столбцу случайной выборки
# Out:
# 21932415.0

# %%
samp10['Agricultural Land( %)'].mean()   #Расчет среднего значения по столбцу случайной выборки
# Out:
# 0.2973

# %%
samp10['Population'].median()            #Расчет медианы по столбцу случайной выборки
# Out:
# 3174753.0

# %%
samp10['Land Area(Km2)'].std()           #Расчет стандартного отклонения по столбцу случайной выборки
# Out:
# 4090045.052236283

# %%
samp10['Population'].max()               #Расчет максимального значения по столбцу случайной выборки
# Out:
# 328239523.0

# %%
samp10['Population'].min()               #Расчет минимального значения по столбцу случайной выборки
# Out:
# 97118.0

# %%
samp10_1=pd.DataFrame(data[['Density\n(P/Km2)','Agricultural Land( %)']].sample(10)).reset_index()  #Создание случайной выборки из 10 строк и 2х столбцов, присвоение ей переменной и сбросом индекса(без этого сравнение не проходило)
samp10_1                  #Вывод данных присвоенной новой переменной
# Out:
#    index Density\n(P/Km2)  Agricultural Land( %)
# 0    121              203                  0.287
# 1      7              104                  0.589
# 2     41               73                  0.276
# 3      5              223                  0.205
# 4    192               56                  0.446
# 5    175              152                  0.702
# 6    116               83                  0.685
# 7     37               46                  0.403
# 8    139              124                  0.469
# 9     62              239                  0.598

# %%
samp10_2=pd.DataFrame(data[['Density\n(P/Km2)','Agricultural Land( %)']].sample(10)).reset_index()   #Создание случайной выборки из 10 строк и 2х столбцов, присвоение ей переменной  и сбросом индекса(без этого сравнение не проходило)
samp10_2                  #Вывод данных присвоенной новой переменной
# Out:
#    index Density\n(P/Km2)  Agricultural Land( %)
# 0     24               83                  0.027
# 1      1              105                  0.431
# 2     72              414                  0.668
# 3    108                5                  0.385
# 4     98              238                  0.322
# 5    160               25                  0.703
# 6     19               20                  0.136
# 7    189               25                  0.153
# 8    100              242                  0.537
# 9    170               95                  0.758

# %%
print(samp10_1>=samp10_2)
# Out:
#    index  Density\n(P/Km2)  Agricultural Land( %)
# 0   True             False                   True
# 1   True             False                   True
# 2  False              True                  False
# 3  False             False                  False
# 4   True              True                   True
# 5   True             False                  False
# 6   True              True                   True
# 7  False              True                   True
# 8   True             False                  False
# 9  False             False                  False

# %%
print(samp10_1==samp10_2)
# Out:
#    index  Density\n(P/Km2)  Agricultural Land( %)
# 0  False             False                  False
# 1  False             False                  False
# 2  False             False                  False
# 3  False             False                  False
# 4  False             False                  False
# 5  False             False                  False
# 6  False             False                  False
# 7  False             False                  False
# 8  False             False                  False
# 9  False             False                  False
